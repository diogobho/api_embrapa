# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
def scrape_viti_brasil(year, ):
    url = f'http://vitibrasil.cnpuv.embrapa.br/index.php?ano={year}&opcao=opt_02'

    response = requests.get(url)

    data = []

    if response.status_code == 200:
        soup = BeautifulSoup(response.content, 'html.parser')

        tabela = ''
        produto = ''
        sub_produto = ''
        quantidade = ''
        ano = str(year)  
        unidade_medida = 'L'  

        
        rows = soup.find_all('tr')

        
        for row in rows:
            
            cells = row.find_all('td')
            
            if cells:
                
                if 'tb_item' in cells[0].get('class', []):
                    produto = cells[0].get_text(strip=True)
                    quantidade = cells[1].get_text(strip=True)
                    
                    data.append({'tabela': tabela, 'produto': produto, 'quantidade': quantidade, 'ano': ano, 'unidade_medida': unidade_medida})
                
                elif 'tb_subitem' in cells[0].get('class', []):
                    sub_produto = cells[0].get_text(strip=True)
                    quantidade = cells[1].get_text(strip=True)
                    
                    data.append({'tabela': tabela, 'produto': produto, 'sub_produto': sub_produto, 'quantidade': quantidade, 'ano': ano, 'unidade_medida': unidade_medida})

    else:
        print('Falha ao acessar o site.')

    df = pd.DataFrame(data)
    #alteração feita para excluir os valores nulos da coluna sub_produto
    df = df.dropna(subset=['sub_produto'])
    df = df[['tabela', 'produto', 'sub_produto', 'quantidade', 'ano', 'unidade_medida']]
    return df

# %%
while True:
    try:
        user_year = int(input(f"Digite o ano desejado (1970-{2020}): "))
        if 1970 <= user_year <= 2022:
            break
        else:
            print(f"Por favor, insira um ano entre 1970 e 2022.")
    except ValueError:
        print("Por favor, insira um ano válido.")

# %%
df = scrape_viti_brasil(user_year)

pd.DataFrame(df)
# Out:
#    tabela                        produto  \
# 1                          VINHO DE MESA
# 2                          VINHO DE MESA
# 3                          VINHO DE MESA
# 5          VINHO FINO DE MESA (VINIFERA)
# 6          VINHO FINO DE MESA (VINIFERA)
# 7          VINHO FINO DE MESA (VINIFERA)
# 9                                   SUCO
# 10                                  SUCO
# 11                                  SUCO
# 12                                  SUCO
# 13                                  SUCO
# 15                             DERIVADOS
# 16                             DERIVADOS
# 17                             DERIVADOS
# 18                             DERIVADOS
# 19                             DERIVADOS
# 20                             DERIVADOS
# 21                             DERIVADOS
# 22                             DERIVADOS
# 23                             DERIVADOS
# 24                             DERIVADOS
# 25                             DERIVADOS
# 26                             DERIVADOS
# 27                             DERIVADOS
# 28                             DERIVADOS
# 29                             DERIVADOS
# 30                             DERIVADOS
# 31                             DERIVADOS
# 32                             DERIVADOS
# 33                             DERIVADOS
# 34                             DERIVADOS
# 35                             DERIVADOS
# 36                             DERIVADOS
# 37                             DERIVADOS
# 38                             DERIVADOS
# 39                             DERIVADOS
# 40                             DERIVADOS
# 41                             DERIVADOS
# 42                             DERIVADOS
# 43                             DERIVADOS
# 44                             DERIVADOS
# 45                             DERIVADOS
# 46                             DERIVADOS
# 47                             DERIVADOS
# 48                             DERIVADOS
# 49                             DERIVADOS
# 50                             DERIVADOS
#
#                                  sub_produto   quantidade   ano unidade_medida
# 1                                      Tinto  208.242.670  2000              L
# 2                                     Branco   44.902.276  2000              L
# 3                                     Rosado   19.880.630  2000              L
# 5                                      Tinto   18.545.613  2000              L
# 6                                     Branco   36.955.126  2000              L
# 7                                     Rosado      709.000  2000              L
# 9                       Suco de uva integral    3.546.779  2000              L
# 10                   Suco de uva concentrado   14.176.000  2000              L
# 11                       Suco de uva adoçado            -  2000              L
# 12                      Suco de uva orgânico            -  2000              L
# 13                 Suco de uva reconstituído            -  2000              L
# 15                                 Espumante       71.410  2000              L
# 16                        Espumante moscatel            -  2000              L
# 17                            Base espumante            -  2000              L
# 18                   Base espumante moscatel            -  2000              L
# 19                Base Champenoise champanha            -  2000              L
# 20                    Base Charmat champanha            -  2000              L
# 21                             Bebida de uva            -  2000              L
# 22                              Polpa de uva            -  2000              L
# 23                             Mosto simples   16.192.018  2000              L
# 24                         Mosto concentrado            -  2000              L
# 25                   Mosto de uva com bagaço            -  2000              L
# 26                        Mosto dessulfitado            -  2000              L
# 27                                  Mistelas       33.000  2000              L
# 28                             Néctar de uva            -  2000              L
# 29                                 Licorosos       21.000  2000              L
# 30                                 Compostos            -  2000              L
# 31                                  Jeropiga            -  2000              L
# 32                                  Filtrado            -  2000              L
# 33                                  Frisante            -  2000              L
# 34                                Vinho leve            -  2000              L
# 35                            Vinho licoroso            -  2000              L
# 36                                    Brandy            -  2000              L
# 37                                 Destilado        1.960  2000              L
# 38                                 Bagaceira       12.700  2000              L
# 39                        Licor de bagaceira            -  2000              L
# 40                                   Vinagre            -  2000              L
# 41                             Borra líquida    9.626.928  2000              L
# 42                                Borra seca            -  2000              L
# 43                            Vinho Composto            -  2000              L
# 44                                     Pisco            -  2000              L
# 45                            Vinho orgânico            -  2000              L
# 46                        Espumante orgânico            -  2000              L
# 47  Destilado alcoólico simples de bagaceira            -  2000              L
# 48                         Vinho acidificado            -  2000              L
# 49             Mosto parcialmente fermentado            -  2000              L
# 50                          Outros derivados            -  2000              L
